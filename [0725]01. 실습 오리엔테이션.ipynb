# %% [markdown]
# ## 실습에는 Google Colab 사용

# %% [markdown]
# # Google Colab이란?
#
# ![img](https://colab.research.google.com/img/colab_favicon_256px.png)
#
# Google Colaboratory&#40;줄여서 'Colab'이라고 함&#41;을 통해 브라우저 내에서 Python 스크립트를 작성하고 실행할 수 있습니다.

# %% [markdown]
# ## 특징
#
# - 별도의 파이썬 설치가 필요없음
# - 데이터 분석에 사용되는 TensorFlow, Keras, matplotlib, scikit-learn, pandas 같은 패키지가 기본으로 설치되어 제공
# - GPU를 무료로 사용 가능
# - 간편한 공유

# %% [markdown]
# ## 주의사항
#
# - Chrome 최신 버전 환경 권장
# - 무료버전에선 12시간 후 세션이 만료됨. 세션 만료 시 런타임 종료
# - 코드 셀과 텍스트 셀로 나뉨. 코드 셀에서 python코드, 텍스트 셀에서 Markdown, 텍스트 에디터 사용 가능
#
# ![img](https://user-images.githubusercontent.com/38336977/173407194-5c85385d-0ef2-43ae-a8f6-e7fd228f8b2b.png)
#
#
# - Colab도 주피터 노트북과 비슷하게 런타임 하나에서 내용이 계속 쌓임. 내용을 바꿔가며 많은 시도를 하는 경우 코드에 에러가 없어도 실행이 안되는 경우가 존재함. 이 경우 런타임 다시 시작으로 내부 초기화 후 다시 실행하면 해결되는 경우가 있음.
#  - 런타임 재시작시 구글 마운트, 불러온 파일, import, 변수등이 전부 초기화됨
#  - 이전에 하던 동작을 이어서 하고 싶으면 해당 부분과 관련된 셀을 전부 한 번 씩 실행 시켜주셔야함.
#  - colab을 통해 만든 파일도 사라지므로 저장하고 싶으면 미리 Mydrive로 옮겨야 함
# (커맨드 혹은 드래그앤 드랍활용)
#
#
# [참고 영상]
#
# <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Colab 소개 영상</a>

# %% [markdown]
# ## 데이터 과학
#
# Colab을 통해 인기 있는 Python 라이브러리를 최대한 활용하여 데이터를 분석하고 시각화할 수 있습니다. 아래 코드 셀에서는 데이터를 <strong>Matplotlib</strong>으로 시각화합니다. 셀을 클릭하면 코드 수정을 바로 시작할 수 있습니다.

# %%
import matplotlib.pyplot as plt

sports = ['Archery','Badminton','Boxing','Judo','Taekwondo', 'Wrestling']
medals = [39, 19, 20, 43, 19, 36]

plt.bar(sports, medals)
plt.ylabel("Medals")
plt.title("Olympic Medals")
plt.show()

# %% [markdown]
# ## 머신러닝
#
# Colab을 사용하면 <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">코드 몇 줄</a>만으로 이미지 데이터세트를 가져오고, 이 데이터세트로 이미지 분류기를 학습시키며, 모델을 평가할 수 있습니다. Colab 메모장은 Google 클라우드 서버에서 코드를 실행하므로 사용 중인 컴퓨터의 성능과 관계없이 <a href="#using-accelerated-hardware">GPU 및 TPU</a>를 포함한 Google 하드웨어의 성능을 활용할 수 있습니다. 브라우저만 있으면 사용 가능합니다.

# %% [markdown]
# ## 추가 리소스
#
# ### Colab에서 메모장 사용하기
# - [Colaboratory 개요](/notebooks/basic_features_overview.ipynb)
# - [Markdown 가이드](/notebooks/markdown_guide.ipynb)
# - [라이브러리 가져오기 및 종속 항목 설치하기](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub에서 노트 저장 및 로드하기](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [대화형 양식](/notebooks/forms.ipynb)
# - [대화형 위젯](/notebooks/widgets.ipynb)
#  [Colab의 TensorFlow 2](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### 데이터로 작업하기
# - [데이터 로드: 드라이브, 스프레드시트, Google Cloud Storage](/notebooks/io.ipynb)
# - [차트: 데이터 시각화하기](/notebooks/charts.ipynb)
# - [BigQuery 시작하기](/notebooks/bigquery.ipynb)
#
# ### 머신러닝 단기집중과정
# 다음은 Google 온라인 머신러닝 과정에서 가져온 일부 메모장입니다. <a href="https://developers.google.com/machine-learning/crash-course/">전체 과정 웹사이트</a>에서 자세한 내용을 확인하세요.
# - [Pandas DataFrame 소개](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [합성 데이터를 사용하는 tf.keras 선형 회귀](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### 가속 하드웨어 사용하기
# - [GPU를 사용한 TensorFlow](/notebooks/gpu.ipynb)
# - [TPU를 사용한 TensorFlow](/notebooks/tpu.ipynb)
#
#   * TPU(Tensor Processing Unit): 구글에서 2016년 5월에 발표한 데이터 분석 및 딥러닝용 NPU를 모아놓은 하드웨어

# %% [markdown]
# ## 추가 설정 관련
#
# 우측 상단의 설정을 통해 간단한 설정 기능을 제공
#
# ![img](https://user-images.githubusercontent.com/38336977/173389909-5526f017-5e72-4b0f-8419-5b279eb9d6e0.png)
#
# 편집기의 설정을 바꾸거나, github와 연동할 수 있음
#
# ![img](https://user-images.githubusercontent.com/38336977/173389996-ca1573ac-832d-498b-93ca-5cf46e3d5732.png)
#
#
# ![img](https://user-images.githubusercontent.com/38336977/173390037-fccbba74-d02f-4e25-85ae-2d1a2066c219.png)

# %% [markdown]
# # Scikit-learn이란?

# %% [markdown]
# ![img](data:image/png;base64,...)
#
# Scikit-Learn 패키지는 머신 러닝 교육 및 실무를 위한 파이썬 패키지로 다음과 같은 구성 요소들을 갖추고 있음.
#
# 참고자료
# * https://notebook.community/junhwanjang/DataSchool/Lecture/12.%20Scikit-Learn%20&%20statsmodels%20%ED%8C%A8%ED%82%A4%EC%A7%80%20%EC%86%8C%EA%B0%9C/1)%20Scikit-Learn%20%ED%8C%A8%ED%82%A4%EC%A7%80%EC%9D%98%20%EC%86%8C%EA%B0%9C)
# * http://suanlab.com/assets/youtubes/ml/ML02.pdf
#
#
# ## scikit-learn 특징
#
# * 벤치마크용 샘플 데이터 세트
# * 데이터 전처리(preprocessing) 기능
# * 다양한 머신러닝 모형(알고리즘)을 하나의 패키지에서 제공
# * 다양한 모형에 대한 평가 기능 제공
#
# * 공식 사이트(http://scikit-learn.org)

# %% [markdown]
# ## 제공하는 머신러닝 모형
#
# ### 지도학습 모형
#
# * Logistic/Ridge/Lasso Regression
# * Support Vector Machines
# * Stochastic Gradient Descent
# * Nearest Neighbor Algorithms
# * Naive Bayes
# * Decision Trees
# * Ensemble methods
#  * Random Forests
# * etc...
#
# ### 비지도학습 모형
#
# * Gaussian mixture models
# * Clustering
#  * K-means
#  * DBSCAN
# * etc...

# %% [markdown]
# ## Scikit-learn의 주요 모듈
#
# scikit-learn은 모듈을 통해 데이터셋, 전처리 기능, feature selection, 알고리즘 등을 제공함.
#
#
# | 모듈 | 설명 |
# |------|------|
# | `sklearn.datasets` | 내장된 예제 데이터 세트 |
# | `sklearn.preprocessing` | 다양한 데이터 전처리 기능 제공 (변환, 정규화, 스케일링 등) |
# | `sklearn.feature_selection` | 특징(feature)를 선택할 수 있는 기능 제공 |
# | `sklearn.feature_extraction` | 특징(feature) 추출에 사용 |
# | `sklearn.decomposition` | 차원 축소 관련 알고리즘 지원 (PCA, NMF, Truncated SVD 등)
# | `sklearn.model_selection` | 교차 검증을 위해 데이터를 학습/테스트용으로 분리, 최적 파라미터를 추출하는 API 제공 (GridSearch 등)
# | `sklearn.metrics` | 분류, 회귀, 클러스터링, Pairwise에 대한 다양한 성능 측정 방법 제공 (Accuracy, Precision, Recall, ROC-AUC, RMSE 등) |
# | `sklearn.pipeline` | 특징 처리 등의 변환과 ML 알고리즘 학습, 예측 등을 묶어서 실행할 수 있는 유틸리티 제공 |
# | `sklearn.linear_model` | 선형 회귀, 릿지(Ridge), 라쏘(Lasso), 로지스틱 회귀 등 회귀 관련 알고리즘과 SGD(Stochastic Gradient Descent) 알고리즘 제공 |
# | `sklearn.svm` | 서포트 벡터 머신 알고리즘 제공 |
# | `sklearn.neighbors` | 최근접 이웃 알고리즘 제공 (k-NN 등)
# | `sklearn.naive_bayes` | 나이브 베이즈 알고리즘 제공 (가우시안 NB, 다항 분포 NB 등) |
# | `sklearn.tree` | 의사 결정 트리 알고리즘 제공 |
# | `sklearn.ensemble` | 앙상블 알고리즘 제공 (Random Forest, AdaBoost, GradientBoost 등) |
# | `sklearn.cluster` | 비지도 클러스터링 알고리즘 제공 (k-Means, 계층형 클러스터링, DBSCAN 등)

# %% [markdown]
# ## Scikit-learn의 Class
#
# * 전처리용 클래스
#  * Transformer 클래스
#    * 자료 변환
#  * 공통 메서드
#    * fit(): 모형 계수 추정, 트레이닝(training)
#    * transform() : 자료 처리
#    * fit_transform() : 모형 계수 추정 및 자료 처리 동시 수행
# * 머신러닝 모형 클래스 그룹
#  * Regressor 클래스
#    * 회귀분석
#  * Classifier 클래스
#    * 분류
#  * Cluster 클래스
#    * 클러스터링
#  * 공통 메서드
#    * fit(): 모형 계수 추정, 트레이닝(training)
#    * predict(): 주어진 x값에 대해 y 예측
#    * score(): 성능 분석
# * Pipeline 클래스
#  * 복수의 Preprocessor와 Model을 연결하여 하나의 Model처럼 행동
#  * Model 클래스가 제공하는 공통 메서드를 모두 제공
#  * pipeline 내부에서 Preprocessor에서 자료를 계속 변형한 후 마지막으로 Model에 입력

# %% [markdown]
# # colab notebook example with scikit-learn linear regression

# %% [markdown]
# ## import libraries, make dataset, make and train LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression

X = [[10.0], [8.0], [13.0], [9.0], [11.0], [14.0], [6.0], [4.0], [12.0], [7.0], [5.0]]
y = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## print result using matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)
plt.plot([0, 14], model.predict([[0], [14]]), c= 'r')

# %% [markdown]
# #Pandas Library
#
# 데이터 분석을 위해서 사용되는 라이브러리로 시리즈와
# 데이터프레임을 통해 자료를 처리한다.
#
# 데이터프레임 생성 방법
# 1. csv, txt 등의 외부 파일을 읽어와 데이터 프레임으로 출력
# 2. 리스트, 딕셔너리등을 통해 직접 데이터프레임을 생성할 수 있음
#
# ![img](https://dandyrilla.github.io/images/2017-08-12/fig0.png)

# %% [markdown]
# ## csv로부터 데이터 읽어오기

# %%
import pandas as pd

df = pd.read_csv('sample_data/california_housing_test.csv')

df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# ### 데이터프레임 일부만 불러오기
#
# 1. 앞에서 불러오기

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# 2. 뒤에서 불러오기

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# ### 특정 column 만 불러오기

# %%
print(df['housing_median_age'])

print(df['total_rooms'])
# Out:
# 0       27.0
# 1       43.0
# 2       27.0
# 3       28.0
# 4       19.0
#         ...
# 2995    23.0
# 2996    27.0
# 2997    10.0
# 2998    40.0
# 2999    42.0
# Name: housing_median_age, Length: 3000, dtype: float64
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %% [markdown]
# # Exercise

# %% [markdown]
# ## 1번 문제
#
# pandas library를 이용하여 'sample_data/california_housing_train.csv' 를 읽고 생성된 dataframe을 출력하시오.

# %% [markdown]
# ## 1번 문제 답안

# %% [markdown]
# ## 2번 문제
#
# median_income을 x축으로, median_house_value를 y축으로 설정한 다음 matplotlib scatter을 이용하여 visualization하시오.
#
# ```python
# # scatter visualization example
# num_friends = [41,  26,  90,  50,  18,  124, 152, 88,  72,  51]
# phone_time =  [4.1, 3.3, 5.7, 4.2, 3.2, 6.4, 6.0, 5.1, 6.2, 3.7]
# plt.xlim(10,160)
# plt.ylim(0,7)
# plt.scatter(num_friends, phone_time)
# plt.show()
# ```

# %% [markdown]
# ## 2번 문제 답안

# %% [markdown]
# ## 3번 문제
#
# median_income을 x축으로, median_house_value를 y축으로 설정한 다음 sklearn LinearRegression()을 이용하여 학습시키시오.
#
# ```python
#
# # x 데이터를 regression에서 쓸 수 있도록 변환이 필요함.
#
# # 기존 x (datatype: Series)
# '''
# 0        1.4936
# 1        1.8200
# 2        1.6509
# 3        3.1917
# 4        1.9250
#           ...
# 16995    2.3571
# 16996    2.5179
# 16997    3.0313
# 16998    1.9797
# 16999    3.0147
# '''
#
# # 변환한 x (datatype: numpy.ndarray)
#
# '''
# [[1.4936]
#  [1.82  ]
#  [1.6509]
#  ...
#  [3.0313]
#  [1.9797]
#  [3.0147]]
# '''
#
# # 변환 코드
# x = x.values.reshape(-1,1)
#
# ```

# %% [markdown]
# ## 3번 문제 답안
